# %% [markdown]
# ### some packages installation

# %%
# !pip install requests
# Out:
# Collecting requests
#   Downloading requests-2.18.4-py2.py3-none-any.whl (88kB)
# Collecting idna<2.7,>=2.5 (from requests)
#   Downloading idna-2.6-py2.py3-none-any.whl (56kB)
# Collecting chardet<3.1.0,>=3.0.2 (from requests)
#   Downloading chardet-3.0.4-py2.py3-none-any.whl (133kB)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\alee2\appdata\local\continuum\anaconda3\envs\athena_practice\lib\site-packages (from requests)
# Collecting urllib3<1.23,>=1.21.1 (from requests)
#   Downloading urllib3-1.22-py2.py3-none-any.whl (132kB)
# Installing collected packages: idna, chardet, urllib3, requests
# Successfully installed chardet-3.0.4 idna-2.6 requests-2.18.4 urllib3-1.22

# %%
# !pip install beautifulsoup4
# Out:
# Collecting beautifulsoup4
#   Downloading beautifulsoup4-4.6.0-py3-none-any.whl (86kB)
# Installing collected packages: beautifulsoup4
# Successfully installed beautifulsoup4-4.6.0

# %%
import requests as r
from bs4 import BeautifulSoup
import urllib.parse

# %% [markdown]
# ###  testing for getting data within a month

# %%
# getting the data within a month (Febuary)

page_url = "http://e-service.cwb.gov.tw/HistoryDataQuery/DayDataController.do?command=viewMain&station=C0A9G0&stname=%25E5%258D%2597%25E6%25B8%25AF&datepicker=2016-02-{}"
date = []

for i in range(1, 30) :
    if i<10 :
        i = "0"+"%s"%i
    #print(i)
    
    feb_page = page_url.format(i)
    #print(feb_page)
    feb_res = r.get(feb_page)
    feb_res.encoding = "utf-8"
    
     
    dates = "2016/02/{}"
    
    date_each = dates.format(i)
    date.append(date_each) 
    
res = r.get(page_url)
res.encoding = 'utf-8' # 調整Response obect的encoding，不然中文是亂碼
soup = BeautifulSoup(res.text, 'html5lib')

# %%
# tesing for integration on the whole crawler
import pprint
import pandas as pd

page_url = "http://e-service.cwb.gov.tw/HistoryDataQuery/DayDataController.do?command=viewMain&station=C0A9G0&stname=%25E5%258D%2597%25E6%25B8%25AF&datepicker={}"
date = []
tr_list = []

for i in range(1, 30) :
    if i<10 :
        i = "0"+"%s"%i
    #print(i)
    
    feb_date = "2016-02-%s"%i
    date_col = []
    date_col.append(feb_date)
    #print(date_col)
    
    feb_page = page_url.format(feb_date)
    #print(feb_page)
    
   
    
    feb_res = r.get(feb_page)
    feb_res.encoding = "utf-8"
    soup = BeautifulSoup(feb_res.text, 'html5lib')
    
    # getting out the data
    
    for i in range(3, 27):
        ii =soup.select("tr" )[i]
        tr_set = "%s"%ii
        tr_set = tr_set.replace("\n\t\t", "").replace("\xa0", "").replace("<tr>", "")\
        .replace("</tr>", "").replace('<td nowrap="">', "").replace("</td>", ",").replace("<td>", "")\
        .replace("\t", "").replace("\n\t", '').replace('\n', '').replace(" ", "")
        # tr_set is still a string now
        tr_set = tr_set.split(",") 
        # for this time, after the action of splitting, tr_set becomes a list !
        
        tr_set.insert(0,feb_date)
        tr_set.pop(16)
        tr_list.append(tr_set)
#pprint.pprint(tr_list)
        
#df = pd.DataFrame(tr_list ,column_names)


date = []
ObsTime = []
StnPres = []
SeaPres = []
Temperature = []
Td_dew_point = []
RH = []
WS = []
WD = []
WSGust = []
WDGust = []
Precp = []
PrecpHour = []
SunShine = []
GloblRad = []
Visb = []



    
for i in tr_list :
    date.append(i[0])
    ObsTime.append(i[1])
    StnPres.append(i[2])
    SeaPres.append(i[3])
    Temperature.append(i[4])
    Td_dew_point.append(i[5])
    RH.append(i[6])
    WS.append(i[7])
    WD.append(i[8])
    WSGust.append(i[9])
    WDGust.append(i[10])
    Precp.append(i[11])
    PrecpHour.append(i[12])
    SunShine.append(i[13])
    GloblRad.append(i[14])
    Visb.append(i[15])

WeatherDataSet = list(zip(date,ObsTime,StnPres,SeaPres,Temperature,Td_dew_point,RH,WS,WD,WSGust,WDGust,Precp,PrecpHour,SunShine,GloblRad,Visb))
WeatherDataSet
df = pd.DataFrame(WeatherDataSet, column_names)    

#df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\envs\athena_practice\lib\site-packages\pandas\core\internals.py in create_block_manager_from_arrays(arrays, names, axes)
#    4637         blocks = form_blocks(arrays, names, axes)
# -> 4638         mgr = BlockManager(blocks, axes)
#    4639         mgr._consolidate_inplace()
#
# ~\AppData\Local\Continuum\anaconda3\envs\athena_practice\lib\site-packages\pandas\core\internals.py in __init__(self, blocks, axes, do_integrity_check, fastpath)
#    3032         if do_integrity_check:
# -> 3033             self._verify_integrity()
#    3034
#
# ~\AppData\Local\Continuum\anaconda3\envs\athena_practice\lib\site-packages\pandas\core\internals.py in _verify_integrity(self)
#    3243             if block._verify_integrity and block.shape[1:] != mgr_shape[1:]:
# -> 3244                 construction_error(tot_items, block.shape[1:], self.axes)
#    3245         if len(self.items) != tot_items:
#
# ~\AppData\Local\Continuum\anaconda3\envs\athena_practice\lib\site-packages\pandas\core\internals.py in construction_error(tot_items, block_shape, axes, e)
#    4607     raise ValueError("Shape of passed values is {0}, indices imply {1}".format(
# -> 4608         passed, implied))
#    4609
#
# ValueError: Shape of passed values is (16, 696), indices imply (16, 16)
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-30-3b78cdd226e5> in <module>()
#      84 WeatherDataSet = list(zip(date,ObsTime,StnPres,SeaPres,Temperature,Td_dew_point,RH,WS,WD,WSGust,WDGust,Precp,PrecpHour,SunShine,GloblRad,Visb))
#      85 WeatherDataSet
# ---> 86 df = pd.DataFrame(WeatherDataSet, column_names)
#      87
#      88 #df
#
# ~\AppData\Local\Continuum\anaconda3\envs\athena_practice\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     380
#     381                     mgr = _arrays_to_mgr(arrays, columns, index, columns,
# --> 382                                          dtype=dtype)
#     383                 else:
#     384                     mgr = self._init_ndarray(data, index, columns, dtype=dtype,
#
# ~\AppData\Local\Continuum\anaconda3\envs\athena_practice\lib\site-packages\pandas\core\frame.py in _arrays_to_mgr(arrays, arr_names, index, columns, dtype)
#    6171     axes = [_ensure_index(columns), _ensure_index(index)]
#    6172
# -> 6173     return create_block_manager_from_arrays(arrays, arr_names, axes)
#    6174
#    6175
#
# ~\AppData\Local\Continuum\anaconda3\envs\athena_practice\lib\site-packages\pandas\core\internals.py in create_block_manager_from_arrays(arrays, names, axes)
#    4640         return mgr
#    4641     except ValueError as e:
# -> 4642         construction_error(len(arrays), arrays[0].shape, axes, e)
#    4643
#    4644
#
# ~\AppData\Local\Continuum\anaconda3\envs\athena_practice\lib\site-packages\pandas\core\internals.py in construction_error(tot_items, block_shape, axes, e)
#    4606         raise ValueError("Empty data passed with indices specified.")
#    4607     raise ValueError("Shape of passed values is {0}, indices imply {1}".format(
# -> 4608         passed, implied))
#    4609
#    4610
#
# ValueError: Shape of passed values is (16, 696), indices imply (16, 16)

# %%
pprint.pprint(tr_list)
# Out:
# [['2016-02-01',
#   '1',
#   '1017.3',
#   '',
#   '17.6',
#   '',
#   '94',
#   '1.2',
#   '74',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-01',
#   '2',
#   '1017.4',
#   '',
#   '17.3',
#   '',
#   '94',
#   '1.3',
#   '81',
#   '',
#   '',
#   '0.5',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-01',
#   '3',
#   '1017.5',
#   '',
#   '17.1',
#   '',
#   '91',
#   '1.2',
#   '69',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-01',
#   '4',
#   '1018.4',
#   '',
#   '16.4',
#   '',
#   '90',
#   '1.3',
#   '61',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-01',
#   '5',
#   '1019.6',
#   '',
#   '15.8',
#   '',
#   '88',
#   '0.9',
#   '67',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-01',
#   '6',
#   '1020.3',
#   '',
#   '15.1',
#   '',
#   '90',
#   '1.3',
#   '68',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-01',
#   '7',
#   '1021.2',
#   '',
#   '14.3',
#   '',
#   '89',
#   '1.3',
#   '68',
#   '',
#   '',
#   '1.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-01',
#   '8',
#   '1022.2',
#   '',
#   '13.7',
#   '',
#   '89',
#   '1.3',
#   '58',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-01',
#   '9',
#   '1022.4',
#   '',
#   '13.8',
#   '',
#   '91',
#   '1.3',
#   '65',
#   '',
#   '',
#   '1.5',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-01',
#   '10',
#   '1022.9',
#   '',
#   '13.9',
#   '',
#   '90',
#   '1.1',
#   '60',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-01',
#   '11',
#   '1022.5',
#   '',
#   '13.9',
#   '',
#   '88',
#   '1.4',
#   '59',
#   '',
#   '',
#   '1.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-01',
#   '12',
#   '1021.6',
#   '',
#   '14.0',
#   '',
#   '90',
#   '0.6',
#   '61',
#   '',
#   '',
#   '0.5',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-01',
#   '13',
#   '1020.9',
#   '',
#   '13.8',
#   '',
#   '91',
#   '0.8',
#   '63',
#   '',
#   '',
#   '2.5',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-01',
#   '14',
#   '1020.2',
#   '',
#   '13.7',
#   '',
#   '90',
#   '0.9',
#   '64',
#   '',
#   '',
#   '1.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-01',
#   '15',
#   '1020.0',
#   '',
#   '13.8',
#   '',
#   '88',
#   '0.9',
#   '62',
#   '',
#   '',
#   '0.5',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-01',
#   '16',
#   '1020.7',
#   '',
#   '13.4',
#   '',
#   '90',
#   '0.7',
#   '69',
#   '',
#   '',
#   '0.5',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-01',
#   '17',
#   '1021.8',
#   '',
#   '13.2',
#   '',
#   '89',
#   '0.9',
#   '38',
#   '',
#   '',
#   '1.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-01',
#   '18',
#   '1022.3',
#   '',
#   '12.6',
#   '',
#   '88',
#   '0.8',
#   '69',
#   '',
#   '',
#   '0.5',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-01',
#   '19',
#   '1023.6',
#   '',
#   '12.3',
#   '',
#   '88',
#   '1.0',
#   '70',
#   '',
#   '',
#   '2.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-01',
#   '20',
#   '1023.5',
#   '',
#   '12.1',
#   '',
#   '89',
#   '0.7',
#   '76',
#   '',
#   '',
#   '0.5',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-01',
#   '21',
#   '1023.4',
#   '',
#   '12.1',
#   '',
#   '90',
#   '0.7',
#   '60',
#   '',
#   '',
#   '1.5',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-01',
#   '22',
#   '1023.3',
#   '',
#   '12.0',
#   '',
#   '90',
#   '0.8',
#   '68',
#   '',
#   '',
#   '1.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-01',
#   '23',
#   '1023.3',
#   '',
#   '11.9',
#   '',
#   '90',
#   '1.0',
#   '70',
#   '',
#   '',
#   '1.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-01',
#   '24',
#   '1022.8',
#   '',
#   '11.9',
#   '',
#   '90',
#   '0.7',
#   '63',
#   '',
#   '',
#   '0.5',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-02',
#   '1',
#   '1022.5',
#   '',
#   '11.8',
#   '',
#   '92',
#   '0.7',
#   '73',
#   '',
#   '',
#   '1.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-02',
#   '2',
#   '1022.3',
#   '',
#   '11.9',
#   '',
#   '92',
#   '0.7',
#   '79',
#   '',
#   '',
#   '1.5',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-02',
#   '3',
#   '1021.6',
#   '',
#   '11.9',
#   '',
#   '91',
#   '0.9',
#   '81',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-02',
#   '4',
#   '1021.8',
#   '',
#   '11.8',
#   '',
#   '92',
#   '0.7',
#   '82',
#   '',
#   '',
#   '2.5',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-02',
#   '5',
#   '1021.7',
#   '',
#   '11.9',
#   '',
#   '91',
#   '0.8',
#   '64',
#   '',
#   '',
#   '2.5',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-02',
#   '6',
#   '1022.3',
#   '',
#   '11.9',
#   '',
#   '91',
#   '0.7',
#   '78',
#   '',
#   '',
#   '1.5',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-02',
#   '7',
#   '1022.6',
#   '',
#   '12.1',
#   '',
#   '90',
#   '0.9',
#   '58',
#   '',
#   '',
#   '0.5',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-02',
#   '8',
#   '1023.4',
#   '',
#   '11.9',
#   '',
#   '91',
#   '0.6',
#   '73',
#   '',
#   '',
#   '0.5',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-02',
#   '9',
#   '1023.5',
#   '',
#   '12.1',
#   '',
#   '92',
#   '0.9',
#   '72',
#   '',
#   '',
#   '0.5',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-02',
#   '10',
#   '1023.8',
#   '',
#   '12.4',
#   '',
#   '88',
#   '0.9',
#   '59',
#   '',
#   '',
#   '0.5',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-02',
#   '11',
#   '1022.8',
#   '',
#   '12.4',
#   '',
#   '91',
#   '0.5',
#   '78',
#   '',
#   '',
#   '0.5',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-02',
#   '12',
#   '1022.2',
#   '',
#   '12.4',
#   '',
#   '88',
#   '0.9',
#   '80',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-02',
#   '13',
#   '1021.2',
#   '',
#   '12.1',
#   '',
#   '88',
#   '0.9',
#   '57',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-02',
#   '14',
#   '1020.6',
#   '',
#   '12.2',
#   '',
#   '89',
#   '0.7',
#   '71',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-02',
#   '15',
#   '1020.3',
#   '',
#   '12.2',
#   '',
#   '89',
#   '0.8',
#   '76',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-02',
#   '16',
#   '1020.3',
#   '',
#   '12.2',
#   '',
#   '92',
#   '0.7',
#   '90',
#   '',
#   '',
#   '0.5',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-02',
#   '17',
#   '1020.6',
#   '',
#   '12.4',
#   '',
#   '93',
#   '0.6',
#   '91',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-02',
#   '18',
#   '1020.8',
#   '',
#   '12.4',
#   '',
#   '94',
#   '0.7',
#   '73',
#   '',
#   '',
#   '0.5',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-02',
#   '19',
#   '1021.2',
#   '',
#   '12.5',
#   '',
#   '92',
#   '0.6',
#   '103',
#   '',
#   '',
#   '0.5',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-02',
#   '20',
#   '1021.5',
#   '',
#   '12.5',
#   '',
#   '94',
#   '0.7',
#   '104',
#   '',
#   '',
#   '0.5',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-02',
#   '21',
#   '1021.8',
#   '',
#   '12.7',
#   '',
#   '95',
#   '0.7',
#   '108',
#   '',
#   '',
#   '1.5',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-02',
#   '22',
#   '1021.8',
#   '',
#   '12.7',
#   '',
#   '95',
#   '0.5',
#   '91',
#   '',
#   '',
#   '1.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-02',
#   '23',
#   '1021.6',
#   '',
#   '12.7',
#   '',
#   '96',
#   '0.5',
#   '98',
#   '',
#   '',
#   '1.5',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-02',
#   '24',
#   '1021.2',
#   '',
#   '12.8',
#   '',
#   '96',
#   '0.6',
#   '96',
#   '',
#   '',
#   '0.5',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-03',
#   '1',
#   '1021.0',
#   '',
#   '12.9',
#   '',
#   '96',
#   '0.7',
#   '119',
#   '',
#   '',
#   '0.5',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-03',
#   '2',
#   '1020.8',
#   '',
#   '13.0',
#   '',
#   '96',
#   '0.6',
#   '109',
#   '',
#   '',
#   '0.5',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-03',
#   '3',
#   '1020.5',
#   '',
#   '13.1',
#   '',
#   '96',
#   '0.8',
#   '110',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-03',
#   '4',
#   '1020.3',
#   '',
#   '13.2',
#   '',
#   '96',
#   '0.5',
#   '103',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-03',
#   '5',
#   '1020.2',
#   '',
#   '13.3',
#   '',
#   '96',
#   '0.9',
#   '121',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-03',
#   '6',
#   '1020.8',
#   '',
#   '13.4',
#   '',
#   '94',
#   '0.8',
#   '72',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-03',
#   '7',
#   '1021.4',
#   '',
#   '13.4',
#   '',
#   '96',
#   '0.6',
#   '111',
#   '',
#   '',
#   '0.5',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-03',
#   '8',
#   '1021.6',
#   '',
#   '13.5',
#   '',
#   '96',
#   '0.6',
#   '91',
#   '',
#   '',
#   '0.5',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-03',
#   '9',
#   '1021.6',
#   '',
#   '13.7',
#   '',
#   '95',
#   '0.8',
#   '91',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-03',
#   '10',
#   '1021.5',
#   '',
#   '14.3',
#   '',
#   '93',
#   '1.1',
#   '81',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-03',
#   '11',
#   '1020.6',
#   '',
#   '15.0',
#   '',
#   '86',
#   '1.2',
#   '80',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-03',
#   '12',
#   '1020.1',
#   '',
#   '15.0',
#   '',
#   '88',
#   '0.9',
#   '91',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-03',
#   '13',
#   '1019.5',
#   '',
#   '14.7',
#   '',
#   '91',
#   '0.9',
#   '77',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-03',
#   '14',
#   '1019.2',
#   '',
#   '14.5',
#   '',
#   '92',
#   '1.0',
#   '73',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-03',
#   '15',
#   '1019.2',
#   '',
#   '14.3',
#   '',
#   '92',
#   '0.8',
#   '97',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-03',
#   '16',
#   '1019.6',
#   '',
#   '14.3',
#   '',
#   '92',
#   '0.8',
#   '86',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-03',
#   '17',
#   '1020.2',
#   '',
#   '14.2',
#   '',
#   '93',
#   '0.8',
#   '91',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-03',
#   '18',
#   '1020.6',
#   '',
#   '14.1',
#   '',
#   '94',
#   '0.7',
#   '89',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-03',
#   '19',
#   '1021.0',
#   '',
#   '14.0',
#   '',
#   '95',
#   '0.7',
#   '107',
#   '',
#   '',
#   '0.5',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-03',
#   '20',
#   '1021.3',
#   '',
#   '14.1',
#   '',
#   '95',
#   '0.6',
#   '109',
#   '',
#   '',
#   '1.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-03',
#   '21',
#   '1021.3',
#   '',
#   '14.4',
#   '',
#   '95',
#   '0.8',
#   '110',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-03',
#   '22',
#   '1021.2',
#   '',
#   '14.7',
#   '',
#   '95',
#   '0.9',
#   '89',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-03',
#   '23',
#   '1021.0',
#   '',
#   '14.9',
#   '',
#   '93',
#   '0.7',
#   '122',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-03',
#   '24',
#   '1020.6',
#   '',
#   '14.9',
#   '',
#   '94',
#   '0.8',
#   '109',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-04',
#   '1',
#   '1020.5',
#   '',
#   '15.0',
#   '',
#   '95',
#   '0.8',
#   '113',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-04',
#   '2',
#   '1020.2',
#   '',
#   '15.0',
#   '',
#   '96',
#   '0.3',
#   '95',
#   '',
#   '',
#   '0.5',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-04',
#   '3',
#   '1019.9',
#   '',
#   '15.1',
#   '',
#   '97',
#   '0.5',
#   '77',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-04',
#   '4',
#   '1019.6',
#   '',
#   '15.2',
#   '',
#   '97',
#   '0.7',
#   '103',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-04',
#   '5',
#   '1019.2',
#   '',
#   '15.2',
#   '',
#   '97',
#   '0.7',
#   '107',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-04',
#   '6',
#   '1019.1',
#   '',
#   '15.3',
#   '',
#   '97',
#   '0.8',
#   '88',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-04',
#   '7',
#   '1019.2',
#   '',
#   '15.3',
#   '',
#   '97',
#   '0.8',
#   '123',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-04',
#   '8',
#   '1019.3',
#   '',
#   '15.9',
#   '',
#   '96',
#   '0.9',
#   '84',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-04',
#   '9',
#   '1019.4',
#   '',
#   '17.8',
#   '',
#   '86',
#   '1.4',
#   '82',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-04',
#   '10',
#   '1019.4',
#   '',
#   '18.8',
#   '',
#   '85',
#   '0.9',
#   '92',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-04',
#   '11',
#   '1018.5',
#   '',
#   '19.8',
#   '',
#   '80',
#   '1.0',
#   '66',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-04',
#   '12',
#   '1017.8',
#   '',
#   '19.8',
#   '',
#   '79',
#   '0.7',
#   '87',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-04',
#   '13',
#   '1016.4',
#   '',
#   '19.4',
#   '',
#   '83',
#   '1.1',
#   '89',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-04',
#   '14',
#   '1015.9',
#   '',
#   '18.5',
#   '',
#   '83',
#   '0.8',
#   '89',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-04',
#   '15',
#   '1015.8',
#   '',
#   '17.9',
#   '',
#   '86',
#   '1.2',
#   '76',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-04',
#   '16',
#   '1015.9',
#   '',
#   '17.8',
#   '',
#   '85',
#   '1.2',
#   '69',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-04',
#   '17',
#   '1016.2',
#   '',
#   '17.6',
#   '',
#   '86',
#   '1.0',
#   '76',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-04',
#   '18',
#   '1016.6',
#   '',
#   '17.4',
#   '',
#   '89',
#   '1.2',
#   '61',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-04',
#   '19',
#   '1017.0',
#   '',
#   '17.2',
#   '',
#   '92',
#   '1.1',
#   '76',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-04',
#   '20',
#   '1017.4',
#   '',
#   '17.1',
#   '',
#   '93',
#   '0.7',
#   '35',
#   '',
#   '',
#   '0.5',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-04',
#   '21',
#   '1017.8',
#   '',
#   '16.9',
#   '',
#   '93',
#   '1.1',
#   '75',
#   '',
#   '',
#   '0.5',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-04',
#   '22',
#   '1017.3',
#   '',
#   '16.7',
#   '',
#   '90',
#   '1.1',
#   '81',
#   '',
#   '',
#   '0.5',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-04',
#   '23',
#   '1017.4',
#   '',
#   '16.5',
#   '',
#   '93',
#   '0.7',
#   '105',
#   '',
#   '',
#   '1.5',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-04',
#   '24',
#   '1017.3',
#   '',
#   '16.4',
#   '',
#   '94',
#   '0.6',
#   '55',
#   '',
#   '',
#   '0.5',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-05',
#   '1',
#   '1017.4',
#   '',
#   '16.1',
#   '',
#   '96',
#   '0.5',
#   '154',
#   '',
#   '',
#   '2.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-05',
#   '2',
#   '1017.0',
#   '',
#   '16.0',
#   '',
#   '96',
#   '0.2',
#   '0',
#   '',
#   '',
#   '0.5',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-05',
#   '3',
#   '1017.1',
#   '',
#   '15.9',
#   '',
#   '95',
#   '0.9',
#   '42',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-05',
#   '4',
#   '1016.3',
#   '',
#   '15.8',
#   '',
#   '93',
#   '1.0',
#   '140',
#   '',
#   '',
#   '1.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-05',
#   '5',
#   '1016.5',
#   '',
#   '16.0',
#   '',
#   '88',
#   '0.6',
#   '225',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-05',
#   '6',
#   '1017.8',
#   '',
#   '15.8',
#   '',
#   '91',
#   '0.4',
#   '263',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-05',
#   '7',
#   '1018.5',
#   '',
#   '15.7',
#   '',
#   '84',
#   '1.1',
#   '87',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-05',
#   '8',
#   '1019.1',
#   '',
#   '15.4',
#   '',
#   '84',
#   '1.0',
#   '74',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-05',
#   '9',
#   '1019.2',
#   '',
#   '15.3',
#   '',
#   '82',
#   '1.3',
#   '60',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-05',
#   '10',
#   '1019.1',
#   '',
#   '15.1',
#   '',
#   '83',
#   '0.8',
#   '67',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-05',
#   '11',
#   '1018.4',
#   '',
#   '15.1',
#   '',
#   '82',
#   '1.3',
#   '50',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-05',
#   '12',
#   '1017.6',
#   '',
#   '15.3',
#   '',
#   '80',
#   '1.0',
#   '77',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-05',
#   '13',
#   '1016.3',
#   '',
#   '15.7',
#   '',
#   '77',
#   '1.3',
#   '44',
#   '',
#   '',
#   '0.5',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-05',
#   '14',
#   '1016.3',
#   '',
#   '15.6',
#   '',
#   '76',
#   '1.2',
#   '36',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-05',
#   '15',
#   '1015.5',
#   '',
#   '15.0',
#   '',
#   '79',
#   '0.8',
#   '53',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-05',
#   '16',
#   '1015.5',
#   '',
#   '14.5',
#   '',
#   '81',
#   '1.2',
#   '78',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-05',
#   '17',
#   '1016.6',
#   '',
#   '14.2',
#   '',
#   '81',
#   '1.0',
#   '51',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-05',
#   '18',
#   '1016.4',
#   '',
#   '14.1',
#   '',
#   '83',
#   '1.1',
#   '62',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-05',
#   '19',
#   '1017.3',
#   '',
#   '14.3',
#   '',
#   '83',
#   '1.2',
#   '58',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-05',
#   '20',
#   '1017.8',
#   '',
#   '14.1',
#   '',
#   '82',
#   '0.9',
#   '45',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-05',
#   '21',
#   '1018.2',
#   '',
#   '14.3',
#   '',
#   '83',
#   '0.9',
#   '59',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-05',
#   '22',
#   '1018.1',
#   '',
#   '13.8',
#   '',
#   '86',
#   '1.4',
#   '54',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-05',
#   '23',
#   '1018.4',
#   '',
#   '13.5',
#   '',
#   '83',
#   '1.1',
#   '59',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-05',
#   '24',
#   '1018.9',
#   '',
#   '13.3',
#   '',
#   '77',
#   '1.2',
#   '60',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-06',
#   '1',
#   '1018.9',
#   '',
#   '13.3',
#   '',
#   '72',
#   '1.1',
#   '44',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-06',
#   '2',
#   '1018.9',
#   '',
#   '13.3',
#   '',
#   '65',
#   '1.1',
#   '39',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-06',
#   '3',
#   '1019.5',
#   '',
#   '13.2',
#   '',
#   '66',
#   '0.8',
#   '8',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-06',
#   '4',
#   '1019.9',
#   '',
#   '13.2',
#   '',
#   '64',
#   '1.1',
#   '19',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-06',
#   '5',
#   '1020.4',
#   '',
#   '13.0',
#   '',
#   '64',
#   '0.9',
#   '38',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-06',
#   '6',
#   '1021.1',
#   '',
#   '12.5',
#   '',
#   '66',
#   '0.7',
#   '219',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-06',
#   '7',
#   '1020.9',
#   '',
#   '12.4',
#   '',
#   '68',
#   '0.8',
#   '163',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-06',
#   '8',
#   '1021.2',
#   '',
#   '11.7',
#   '',
#   '78',
#   '0.3',
#   '252',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-06',
#   '9',
#   '1022.0',
#   '',
#   '11.9',
#   '',
#   '75',
#   '0.7',
#   '232',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-06',
#   '10',
#   '1022.2',
#   '',
#   '12.5',
#   '',
#   '56',
#   '0.9',
#   '20',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-06',
#   '11',
#   '1022.2',
#   '',
#   '12.2',
#   '',
#   '57',
#   '0.8',
#   '65',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-06',
#   '12',
#   '1022.2',
#   '',
#   '12.1',
#   '',
#   '53',
#   '0.6',
#   '292',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-06',
#   '13',
#   '1021.6',
#   '',
#   '12.1',
#   '',
#   '50',
#   '1.5',
#   '11',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-06',
#   '14',
#   '1021.2',
#   '',
#   '11.8',
#   '',
#   '52',
#   '1.4',
#   '6',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-06',
#   '15',
#   '1021.4',
#   '',
#   '11.9',
#   '',
#   '50',
#   '1.1',
#   '11',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-06',
#   '16',
#   '1021.6',
#   '',
#   '12.0',
#   '',
#   '47',
#   '2.1',
#   '32',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-06',
#   '17',
#   '1022.6',
#   '',
#   '11.6',
#   '',
#   '43',
#   '1.5',
#   '35',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-06',
#   '18',
#   '1023.2',
#   '',
#   '11.2',
#   '',
#   '45',
#   '1.5',
#   '35',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-06',
#   '19',
#   '1024.1',
#   '',
#   '10.9',
#   '',
#   '46',
#   '1.4',
#   '331',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-06',
#   '20',
#   '1025.1',
#   '',
#   '10.7',
#   '',
#   '45',
#   '0.6',
#   '310',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-06',
#   '21',
#   '1025.4',
#   '',
#   '10.2',
#   '',
#   '54',
#   '0.6',
#   '163',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-06',
#   '22',
#   '1025.4',
#   '',
#   '11.0',
#   '',
#   '52',
#   '1.1',
#   '13',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-06',
#   '23',
#   '1025.3',
#   '',
#   '11.2',
#   '',
#   '50',
#   '0.7',
#   '19',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-06',
#   '24',
#   '1024.9',
#   '',
#   '11.3',
#   '',
#   '49',
#   '0.9',
#   '6',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-07',
#   '1',
#   '1025.0',
#   '',
#   '10.3',
#   '',
#   '60',
#   '0.7',
#   '260',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-07',
#   '2',
#   '1024.7',
#   '',
#   '10.3',
#   '',
#   '62',
#   '1.1',
#   '216',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-07',
#   '3',
#   '1024.2',
#   '',
#   '9.9',
#   '',
#   '64',
#   '0.5',
#   '200',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-07',
#   '4',
#   '1024.0',
#   '',
#   '9.0',
#   '',
#   '69',
#   '0.5',
#   '120',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-07',
#   '5',
#   '1023.6',
#   '',
#   '8.8',
#   '',
#   '72',
#   '0.8',
#   '191',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-07',
#   '6',
#   '1023.6',
#   '',
#   '8.8',
#   '',
#   '71',
#   '0.4',
#   '138',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-07',
#   '7',
#   '1023.9',
#   '',
#   '8.6',
#   '',
#   '75',
#   '0.6',
#   '81',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-07',
#   '8',
#   '1024.0',
#   '',
#   '9.0',
#   '',
#   '75',
#   '0.1',
#   '0',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-07',
#   '9',
#   '1024.3',
#   '',
#   '11.1',
#   '',
#   '66',
#   '0.6',
#   '157',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-07',
#   '10',
#   '1024.0',
#   '',
#   '12.9',
#   '',
#   '44',
#   '1.8',
#   '48',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-07',
#   '11',
#   '1023.2',
#   '',
#   '13.8',
#   '',
#   '41',
#   '1.8',
#   '77',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-07',
#   '12',
#   '1022.4',
#   '',
#   '14.1',
#   '',
#   '40',
#   '0.9',
#   '145',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-07',
#   '13',
#   '1021.4',
#   '',
#   '14.3',
#   '',
#   '42',
#   '2.0',
#   '37',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-07',
#   '14',
#   '1020.6',
#   '',
#   '14.0',
#   '',
#   '44',
#   '1.8',
#   '50',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-07',
#   '15',
#   '1020.4',
#   '',
#   '14.0',
#   '',
#   '44',
#   '1.3',
#   '64',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-07',
#   '16',
#   '1020.5',
#   '',
#   '13.7',
#   '',
#   '41',
#   '1.6',
#   '72',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-07',
#   '17',
#   '1021.5',
#   '',
#   '13.0',
#   '',
#   '44',
#   '1.2',
#   '63',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-07',
#   '18',
#   '1021.9',
#   '',
#   '12.1',
#   '',
#   '44',
#   '1.3',
#   '68',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-07',
#   '19',
#   '1022.6',
#   '',
#   '10.9',
#   '',
#   '49',
#   '1.0',
#   '155',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-07',
#   '20',
#   '1022.9',
#   '',
#   '9.8',
#   '',
#   '59',
#   '0.9',
#   '135',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-07',
#   '21',
#   '1023.5',
#   '',
#   '9.2',
#   '',
#   '64',
#   '0.8',
#   '129',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-07',
#   '22',
#   '1023.8',
#   '',
#   '9.0',
#   '',
#   '65',
#   '0.9',
#   '135',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-07',
#   '23',
#   '1023.7',
#   '',
#   '8.1',
#   '',
#   '70',
#   '0.6',
#   '166',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-07',
#   '24',
#   '1023.4',
#   '',
#   '7.6',
#   '',
#   '73',
#   '0.6',
#   '183',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-08',
#   '1',
#   '1023.3',
#   '',
#   '7.4',
#   '',
#   '76',
#   '0.5',
#   '173',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-08',
#   '2',
#   '1023.2',
#   '',
#   '7.2',
#   '',
#   '76',
#   '0.5',
#   '137',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-08',
#   '3',
#   '1022.6',
#   '',
#   '7.0',
#   '',
#   '78',
#   '0.6',
#   '143',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-08',
#   '4',
#   '1022.6',
#   '',
#   '6.9',
#   '',
#   '79',
#   '0.3',
#   '144',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-08',
#   '5',
#   '1022.7',
#   '',
#   '6.5',
#   '',
#   '77',
#   '0.4',
#   '140',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-08',
#   '6',
#   '1022.9',
#   '',
#   '6.2',
#   '',
#   '78',
#   '0.7',
#   '129',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-08',
#   '7',
#   '1023.2',
#   '',
#   '6.3',
#   '',
#   '75',
#   '0.1',
#   '0',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-08',
#   '8',
#   '1023.5',
#   '',
#   '8.9',
#   '',
#   '65',
#   '0.5',
#   '91',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-08',
#   '9',
#   '1023.6',
#   '',
#   '11.1',
#   '',
#   '57',
#   '0.6',
#   '194',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-08',
#   '10',
#   '1023.3',
#   '',
#   '14.1',
#   '',
#   '45',
#   '0.7',
#   '266',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-08',
#   '11',
#   '1022.4',
#   '',
#   '16.2',
#   '',
#   '29',
#   '1.3',
#   '150',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-08',
#   '12',
#   '1021.2',
#   '',
#   '17.8',
#   '',
#   '25',
#   '1.1',
#   '131',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-08',
#   '13',
#   '1019.9',
#   '',
#   '18.8',
#   '',
#   '23',
#   '1.4',
#   '71',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-08',
#   '14',
#   '1018.9',
#   '',
#   '18.6',
#   '',
#   '27',
#   '1.6',
#   '46',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-08',
#   '15',
#   '1018.4',
#   '',
#   '18.6',
#   '',
#   '28',
#   '1.7',
#   '40',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-08',
#   '16',
#   '1018.6',
#   '',
#   '18.0',
#   '',
#   '35',
#   '2.0',
#   '59',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-08',
#   '17',
#   '1019.1',
#   '',
#   '17.0',
#   '',
#   '38',
#   '2.1',
#   '50',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-08',
#   '18',
#   '1019.5',
#   '',
#   '16.0',
#   '',
#   '42',
#   '1.2',
#   '70',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-08',
#   '19',
#   '1020.0',
#   '',
#   '14.9',
#   '',
#   '49',
#   '0.9',
#   '80',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-08',
#   '20',
#   '1020.4',
#   '',
#   '13.0',
#   '',
#   '62',
#   '1.1',
#   '112',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-08',
#   '21',
#   '1020.6',
#   '',
#   '12.0',
#   '',
#   '67',
#   '0.9',
#   '117',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-08',
#   '22',
#   '1020.6',
#   '',
#   '11.5',
#   '',
#   '69',
#   '1.1',
#   '106',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-08',
#   '23',
#   '1020.2',
#   '',
#   '11.0',
#   '',
#   '72',
#   '0.9',
#   '113',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-08',
#   '24',
#   '1020.2',
#   '',
#   '10.5',
#   '',
#   '74',
#   '0.7',
#   '146',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-09',
#   '1',
#   '1019.9',
#   '',
#   '9.8',
#   '',
#   '81',
#   '0.3',
#   '118',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-09',
#   '2',
#   '1019.4',
#   '',
#   '9.4',
#   '',
#   '82',
#   '0.3',
#   '107',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-09',
#   '3',
#   '1018.8',
#   '',
#   '8.8',
#   '',
#   '85',
#   '0.2',
#   '0',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-09',
#   '4',
#   '1018.4',
#   '',
#   '8.4',
#   '',
#   '86',
#   '0.8',
#   '137',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-09',
#   '5',
#   '1018.6',
#   '',
#   '8.3',
#   '',
#   '86',
#   '0.4',
#   '130',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-09',
#   '6',
#   '1018.9',
#   '',
#   '8.2',
#   '',
#   '86',
#   '0.8',
#   '83',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-09',
#   '7',
#   '1019.4',
#   '',
#   '8.4',
#   '',
#   '85',
#   '0.6',
#   '59',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-09',
#   '8',
#   '1019.8',
#   '',
#   '10.7',
#   '',
#   '75',
#   '0.0',
#   '0',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-09',
#   '9',
#   '1019.9',
#   '',
#   '14.4',
#   '',
#   '62',
#   '0.2',
#   '0',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-09',
#   '10',
#   '1019.8',
#   '',
#   '19.3',
#   '',
#   '48',
#   '0.1',
#   '0',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-09',
#   '11',
#   '1019.1',
#   '',
#   '21.3',
#   '',
#   '37',
#   '1.4',
#   '31',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-09',
#   '12',
#   '1018.0',
#   '',
#   '23.0',
#   '',
#   '30',
#   '1.3',
#   '99',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-09',
#   '13',
#   '1017.2',
#   '',
#   '23.5',
#   '',
#   '25',
#   '2.3',
#   '190',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-09',
#   '14',
#   '1016.4',
#   '',
#   '23.4',
#   '',
#   '29',
#   '2.3',
#   '190',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-09',
#   '15',
#   '1016.2',
#   '',
#   '23.3',
#   '',
#   '32',
#   '2.6',
#   '180',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-09',
#   '16',
#   '1016.3',
#   '',
#   '22.2',
#   '',
#   '40',
#   '2.2',
#   '193',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-09',
#   '17',
#   '1016.8',
#   '',
#   '21.2',
#   '',
#   '48',
#   '1.0',
#   '148',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-09',
#   '18',
#   '1017.4',
#   '',
#   '19.5',
#   '',
#   '54',
#   '1.0',
#   '138',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-09',
#   '19',
#   '1017.5',
#   '',
#   '18.5',
#   '',
#   '60',
#   '0.6',
#   '108',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-09',
#   '20',
#   '1017.7',
#   '',
#   '17.1',
#   '',
#   '67',
#   '0.7',
#   '109',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-09',
#   '21',
#   '1017.8',
#   '',
#   '16.2',
#   '',
#   '71',
#   '1.1',
#   '100',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-09',
#   '22',
#   '1017.4',
#   '',
#   '16.0',
#   '',
#   '72',
#   '0.7',
#   '92',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-09',
#   '23',
#   '1017.1',
#   '',
#   '15.6',
#   '',
#   '73',
#   '1.0',
#   '116',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-09',
#   '24',
#   '1016.9',
#   '',
#   '15.7',
#   '',
#   '73',
#   '1.1',
#   '109',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-10',
#   '1',
#   '1016.7',
#   '',
#   '15.5',
#   '',
#   '74',
#   '0.8',
#   '121',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-10',
#   '2',
#   '1016.0',
#   '',
#   '15.4',
#   '',
#   '76',
#   '1.4',
#   '111',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-10',
#   '3',
#   '1015.4',
#   '',
#   '15.1',
#   '',
#   '79',
#   '0.6',
#   '95',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-10',
#   '4',
#   '1015.0',
#   '',
#   '14.7',
#   '',
#   '82',
#   '1.0',
#   '98',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-10',
#   '5',
#   '1015.2',
#   '',
#   '13.7',
#   '',
#   '86',
#   '0.5',
#   '15',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-10',
#   '6',
#   '1015.8',
#   '',
#   '13.3',
#   '',
#   '87',
#   '0.1',
#   '0',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-10',
#   '7',
#   '1016.6',
#   '',
#   '13.2',
#   '',
#   '86',
#   '0.1',
#   '0',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-10',
#   '8',
#   '1017.4',
#   '',
#   '15.1',
#   '',
#   '73',
#   '1.3',
#   '262',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-10',
#   '9',
#   '1017.9',
#   '',
#   '17.8',
#   '',
#   '59',
#   '0.9',
#   '241',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-10',
#   '10',
#   '1017.7',
#   '',
#   '20.2',
#   '',
#   '49',
#   '0.7',
#   '307',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-10',
#   '11',
#   '1016.7',
#   '',
#   '23.8',
#   '',
#   '41',
#   '2.5',
#   '178',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-10',
#   '12',
#   '1015.6',
#   '',
#   '24.9',
#   '',
#   '37',
#   '1.2',
#   '185',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-10',
#   '13',
#   '1014.4',
#   '',
#   '25.2',
#   '',
#   '38',
#   '2.0',
#   '194',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-10',
#   '14',
#   '1013.6',
#   '',
#   '25.4',
#   '',
#   '41',
#   '2.3',
#   '176',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-10',
#   '15',
#   '1013.4',
#   '',
#   '24.3',
#   '',
#   '49',
#   '2.8',
#   '189',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-10',
#   '16',
#   '1013.6',
#   '',
#   '23.8',
#   '',
#   '52',
#   '2.2',
#   '167',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-10',
#   '17',
#   '1014.0',
#   '',
#   '23.1',
#   '',
#   '56',
#   '1.2',
#   '165',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-10',
#   '18',
#   '1014.0',
#   '',
#   '21.9',
#   '',
#   '61',
#   '1.2',
#   '74',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-10',
#   '19',
#   '1014.2',
#   '',
#   '21.4',
#   '',
#   '64',
#   '1.7',
#   '53',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-10',
#   '20',
#   '1014.2',
#   '',
#   '20.9',
#   '',
#   '67',
#   '0.6',
#   '333',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-10',
#   '21',
#   '1014.0',
#   '',
#   '21.3',
#   '',
#   '66',
#   '0.6',
#   '130',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-10',
#   '22',
#   '1014.0',
#   '',
#   '21.5',
#   '',
#   '64',
#   '0.8',
#   '80',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-10',
#   '23',
#   '1013.4',
#   '',
#   '22.1',
#   '',
#   '59',
#   '0.4',
#   '216',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-10',
#   '24',
#   '1013.5',
#   '',
#   '21.7',
#   '',
#   '62',
#   '0.8',
#   '319',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-11',
#   '1',
#   '1012.8',
#   '',
#   '22.1',
#   '',
#   '58',
#   '1.3',
#   '104',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-11',
#   '2',
#   '1011.8',
#   '',
#   '22.0',
#   '',
#   '57',
#   '1.0',
#   '126',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-11',
#   '3',
#   '1011.4',
#   '',
#   '22.0',
#   '',
#   '60',
#   '1.7',
#   '185',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-11',
#   '4',
#   '1012.2',
#   '',
#   '21.8',
#   '',
#   '63',
#   '1.7',
#   '155',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-11',
#   '5',
#   '1011.7',
#   '',
#   '21.5',
#   '',
#   '65',
#   '1.0',
#   '40',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-11',
#   '6',
#   '1012.4',
#   '',
#   '21.6',
#   '',
#   '66',
#   '1.2',
#   '102',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-11',
#   '7',
#   '1013.9',
#   '',
#   '18.2',
#   '',
#   '74',
#   '2.1',
#   '261',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-11',
#   '8',
#   '1015.2',
#   '',
#   '17.9',
#   '',
#   '82',
#   '1.3',
#   '268',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-11',
#   '9',
#   '1015.3',
#   '',
#   '17.8',
#   '',
#   '84',
#   '1.0',
#   '201',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-11',
#   '10',
#   '1014.4',
#   '',
#   '19.5',
#   '',
#   '77',
#   '1.6',
#   '40',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-11',
#   '11',
#   '1012.6',
#   '',
#   '22.7',
#   '',
#   '66',
#   '1.4',
#   '78',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-11',
#   '12',
#   '1011.4',
#   '',
#   '26.7',
#   '',
#   '56',
#   '1.4',
#   '70',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-11',
#   '13',
#   '1010.7',
#   '',
#   '26.6',
#   '',
#   '57',
#   '2.4',
#   '167',
#   '',
#   '',
#   'X',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-11',
#   '14',
#   '1010.5',
#   '',
#   '23.4',
#   '',
#   '67',
#   '2.0',
#   '268',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-11',
#   '15',
#   '1011.0',
#   '',
#   '21.2',
#   '',
#   '74',
#   '2.3',
#   '278',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-11',
#   '16',
#   'X',
#   '',
#   'X',
#   '',
#   'X',
#   'X',
#   'X',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-11',
#   '17',
#   '1012.1',
#   '',
#   '20.3',
#   '',
#   '78',
#   '1.7',
#   '273',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-11',
#   '18',
#   '1013.4',
#   '',
#   '19.0',
#   '',
#   '86',
#   '1.2',
#   '282',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-11',
#   '19',
#   '1014.0',
#   '',
#   '19.3',
#   '',
#   '83',
#   '0.8',
#   '273',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-11',
#   '20',
#   '1013.9',
#   '',
#   '19.7',
#   '',
#   '80',
#   '1.1',
#   '200',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-11',
#   '21',
#   '1013.9',
#   '',
#   '19.8',
#   '',
#   '81',
#   '0.7',
#   '235',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-11',
#   '22',
#   '1013.1',
#   '',
#   '19.6',
#   '',
#   '82',
#   '0.0',
#   '0',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-11',
#   '23',
#   '1012.1',
#   '',
#   '19.3',
#   '',
#   '83',
#   '0.3',
#   '181',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-11',
#   '24',
#   '1011.8',
#   '',
#   '19.0',
#   '',
#   '85',
#   '1.0',
#   '137',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-12',
#   '1',
#   '1011.5',
#   '',
#   '19.0',
#   '',
#   '84',
#   '0.5',
#   '161',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-12',
#   '2',
#   '1011.8',
#   '',
#   '19.1',
#   '',
#   '83',
#   '0.5',
#   '79',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-12',
#   '3',
#   '1012.3',
#   '',
#   '18.9',
#   '',
#   '85',
#   '1.2',
#   '133',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-12',
#   '4',
#   '1012.0',
#   '',
#   '18.9',
#   '',
#   '85',
#   '0.1',
#   '0',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-12',
#   '5',
#   '1012.3',
#   '',
#   '18.4',
#   '',
#   '87',
#   '0.5',
#   '95',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-12',
#   '6',
#   'X',
#   '',
#   'X',
#   '',
#   'X',
#   'X',
#   'X',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-12',
#   '7',
#   '1013.3',
#   '',
#   '18.1',
#   '',
#   '88',
#   '0.0',
#   '0',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-12',
#   '8',
#   '1012.9',
#   '',
#   '19.1',
#   '',
#   '83',
#   '1.1',
#   '69',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-12',
#   '9',
#   '1013.2',
#   '',
#   '21.2',
#   '',
#   '74',
#   '0.8',
#   '156',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-12',
#   '10',
#   '1013.0',
#   '',
#   '23.8',
#   '',
#   '65',
#   '0.6',
#   '179',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-12',
#   '11',
#   '1012.5',
#   '',
#   '25.8',
#   '',
#   '57',
#   '1.4',
#   '256',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-12',
#   '12',
#   '1011.7',
#   '',
#   '25.2',
#   '',
#   '62',
#   '1.1',
#   '272',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-12',
#   '13',
#   '1010.5',
#   '',
#   '26.1',
#   '',
#   '61',
#   '1.5',
#   '47',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-12',
#   '14',
#   '1009.4',
#   '',
#   '25.5',
#   '',
#   '65',
#   '1.7',
#   '82',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-12',
#   '15',
#   '1008.6',
#   '',
#   '26.8',
#   '',
#   '62',
#   '1.5',
#   '90',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-12',
#   '16',
#   '1008.9',
#   '',
#   '25.4',
#   '',
#   '67',
#   '1.8',
#   '45',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-12',
#   '17',
#   '1009.3',
#   '',
#   '24.7',
#   '',
#   '72',
#   '1.3',
#   '73',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-12',
#   '18',
#   '1009.8',
#   '',
#   '23.6',
#   '',
#   '77',
#   '1.2',
#   '67',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-12',
#   '19',
#   '1009.8',
#   '',
#   '23.0',
#   '',
#   '80',
#   '1.0',
#   '88',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-12',
#   '20',
#   '1010.2',
#   '',
#   '22.4',
#   '',
#   '83',
#   '0.3',
#   '123',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-12',
#   '21',
#   '1009.8',
#   '',
#   '21.3',
#   '',
#   '86',
#   '1.3',
#   '97',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-12',
#   '22',
#   '1009.2',
#   '',
#   '21.1',
#   '',
#   '87',
#   '1.0',
#   '74',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-12',
#   '23',
#   '1009.3',
#   '',
#   '20.3',
#   '',
#   '89',
#   '0.0',
#   '0',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-12',
#   '24',
#   '1009.7',
#   '',
#   '20.3',
#   '',
#   '90',
#   '0.7',
#   '258',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-13',
#   '1',
#   '1009.9',
#   '',
#   '20.4',
#   '',
#   '90',
#   '0.5',
#   '215',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-13',
#   '2',
#   '1009.6',
#   '',
#   '20.1',
#   '',
#   '90',
#   '0.6',
#   '55',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-13',
#   '3',
#   '1009.8',
#   '',
#   '19.6',
#   '',
#   '91',
#   '0.3',
#   '216',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-13',
#   '4',
#   '1009.8',
#   '',
#   '19.1',
#   '',
#   '93',
#   '0.1',
#   '0',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-13',
#   '5',
#   '1009.8',
#   '',
#   '18.9',
#   '',
#   '93',
#   '0.2',
#   '0',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-13',
#   '6',
#   '1010.4',
#   '',
#   '18.8',
#   '',
#   '94',
#   '0.4',
#   '97',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-13',
#   '7',
#   '1010.5',
#   '',
#   '18.7',
#   '',
#   '93',
#   '0.8',
#   '133',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-13',
#   '8',
#   '1010.8',
#   '',
#   '19.6',
#   '',
#   '90',
#   '0.9',
#   '201',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-13',
#   '9',
#   '1010.2',
#   '',
#   '22.6',
#   '',
#   '77',
#   '1.2',
#   '321',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-13',
#   '10',
#   '1009.8',
#   '',
#   '25.0',
#   '',
#   '66',
#   '1.1',
#   '265',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-13',
#   '11',
#   '1009.2',
#   '',
#   '28.2',
#   '',
#   '51',
#   '1.6',
#   '256',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-13',
#   '12',
#   '1008.8',
#   '',
#   '27.5',
#   '',
#   '50',
#   '2.7',
#   '262',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-13',
#   '13',
#   '1008.1',
#   '',
#   '27.8',
#   '',
#   '51',
#   '1.8',
#   '69',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-13',
#   '14',
#   '1007.1',
#   '',
#   '28.8',
#   '',
#   '47',
#   '3.3',
#   '49',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-13',
#   '15',
#   '1007.5',
#   '',
#   '28.5',
#   '',
#   '50',
#   '2.7',
#   '310',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-13',
#   '16',
#   '1007.7',
#   '',
#   '27.0',
#   '',
#   '57',
#   '3.2',
#   '289',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-13',
#   '17',
#   '1008.2',
#   '',
#   '26.2',
#   '',
#   '62',
#   '2.6',
#   '302',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-13',
#   '18',
#   '1009.0',
#   '',
#   '24.8',
#   '',
#   '72',
#   '1.4',
#   '294',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-13',
#   '19',
#   '1009.7',
#   '',
#   '24.9',
#   '',
#   '71',
#   '1.6',
#   '283',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-13',
#   '20',
#   '1009.8',
#   '',
#   '24.1',
#   '',
#   '76',
#   '1.1',
#   '151',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-13',
#   '21',
#   '1009.8',
#   '',
#   '22.9',
#   '',
#   '82',
#   '1.4',
#   '135',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-13',
#   '22',
#   '1009.8',
#   '',
#   '22.8',
#   '',
#   '81',
#   '0.4',
#   '186',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-13',
#   '23',
#   '1009.8',
#   '',
#   '22.0',
#   '',
#   '85',
#   '0.2',
#   '0',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-13',
#   '24',
#   '1009.8',
#   '',
#   '21.5',
#   '',
#   '86',
#   '1.1',
#   '137',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-14',
#   '1',
#   '1009.8',
#   '',
#   '20.9',
#   '',
#   '88',
#   '0.0',
#   '0',
#   '',
#   '',
#   'X',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-14',
#   '2',
#   '1009.4',
#   '',
#   '20.5',
#   '',
#   '89',
#   '0.4',
#   '124',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-14',
#   '3',
#   '1009.2',
#   '',
#   '20.0',
#   '',
#   '90',
#   '1.0',
#   '81',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-14',
#   '4',
#   '1009.4',
#   '',
#   '20.0',
#   '',
#   '91',
#   '0.0',
#   '0',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-14',
#   '5',
#   '1009.6',
#   '',
#   '19.7',
#   '',
#   '91',
#   '0.4',
#   '122',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-14',
#   '6',
#   '1010.2',
#   '',
#   '19.8',
#   '',
#   '91',
#   '0.0',
#   '0',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-14',
#   '7',
#   '1010.9',
#   '',
#   '19.8',
#   '',
#   '91',
#   '0.6',
#   '251',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-14',
#   '8',
#   '1011.6',
#   '',
#   '20.3',
#   '',
#   '89',
#   '0.8',
#   '200',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-14',
#   '9',
#   '1012.4',
#   '',
#   '21.1',
#   '',
#   '86',
#   '0.9',
#   '167',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-14',
#   '10',
#   '1013.0',
#   '',
#   '20.6',
#   '',
#   '85',
#   '2.4',
#   '82',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-14',
#   '11',
#   '1013.1',
#   '',
#   '19.4',
#   '',
#   '81',
#   '2.8',
#   '55',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-14',
#   '12',
#   '1013.6',
#   '',
#   '17.7',
#   '',
#   '87',
#   '1.8',
#   '47',
#   '',
#   '',
#   '1.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-14',
#   '13',
#   '1013.3',
#   '',
#   '16.9',
#   '',
#   '86',
#   '2.8',
#   '54',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-14',
#   '14',
#   '1013.2',
#   '',
#   '16.1',
#   '',
#   '87',
#   '1.9',
#   '48',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-14',
#   '15',
#   '1014.1',
#   '',
#   '15.4',
#   '',
#   '90',
#   '1.6',
#   '64',
#   '',
#   '',
#   '0.5',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-14',
#   '16',
#   '1015.5',
#   '',
#   '14.8',
#   '',
#   '87',
#   '2.0',
#   '55',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-14',
#   '17',
#   '1016.4',
#   '',
#   '14.1',
#   '',
#   '86',
#   '1.8',
#   '50',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-14',
#   '18',
#   '1017.5',
#   '',
#   '13.2',
#   '',
#   '86',
#   '2.0',
#   '47',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-14',
#   '19',
#   '1018.4',
#   '',
#   '12.6',
#   '',
#   '86',
#   '2.2',
#   '32',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-14',
#   '20',
#   '1019.4',
#   '',
#   '12.3',
#   '',
#   '86',
#   '1.3',
#   '56',
#   '',
#   '',
#   '0.5',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-14',
#   '21',
#   '1020.6',
#   '',
#   '12.0',
#   '',
#   '88',
#   '1.5',
#   '50',
#   '',
#   '',
#   '0.5',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-14',
#   '22',
#   '1021.6',
#   '',
#   '11.5',
#   '',
#   '86',
#   '1.4',
#   '38',
#   '',
#   '',
#   '1.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-14',
#   '23',
#   '1022.2',
#   '',
#   '11.4',
#   '',
#   '84',
#   '1.2',
#   '42',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-14',
#   '24',
#   '1022.4',
#   '',
#   '11.3',
#   '',
#   '82',
#   '1.7',
#   '42',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-15',
#   '1',
#   '1022.5',
#   '',
#   '11.0',
#   '',
#   '86',
#   '1.3',
#   '42',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-15',
#   '2',
#   '1022.8',
#   '',
#   '11.0',
#   '',
#   '84',
#   '1.0',
#   '46',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-15',
#   '3',
#   '1022.7',
#   '',
#   '10.7',
#   '',
#   '84',
#   '1.1',
#   '50',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-15',
#   '4',
#   '1023.2',
#   '',
#   '10.4',
#   '',
#   '81',
#   '1.6',
#   '40',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-15',
#   '5',
#   '1022.8',
#   '',
#   '10.1',
#   '',
#   '81',
#   '0.9',
#   '66',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-15',
#   '6',
#   '1023.2',
#   '',
#   '10.1',
#   '',
#   '83',
#   '0.9',
#   '57',
#   '',
#   '',
#   '0.5',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-15',
#   '7',
#   '1023.7',
#   '',
#   '10.1',
#   '',
#   '87',
#   '0.7',
#   '189',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-15',
#   '8',
#   '1024.1',
#   '',
#   '10.4',
#   '',
#   '88',
#   '0.5',
#   '140',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-15',
#   '9',
#   '1024.4',
#   '',
#   '10.6',
#   '',
#   '86',
#   '1.1',
#   '144',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-15',
#   '10',
#   '1024.1',
#   '',
#   '10.6',
#   '',
#   '89',
#   '0.6',
#   '135',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-15',
#   '11',
#   '1023.5',
#   '',
#   '10.7',
#   '',
#   '89',
#   '0.7',
#   '126',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-15',
#   '12',
#   '1022.9',
#   '',
#   '11.4',
#   '',
#   '80',
#   '1.0',
#   '57',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-15',
#   '13',
#   '1022.3',
#   '',
#   '11.1',
#   '',
#   '81',
#   '1.2',
#   '52',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-15',
#   '14',
#   '1021.9',
#   '',
#   '10.6',
#   '',
#   '81',
#   '1.1',
#   '56',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-15',
#   '15',
#   '1021.6',
#   '',
#   '10.6',
#   '',
#   '80',
#   '1.1',
#   '53',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-15',
#   '16',
#   '1021.8',
#   '',
#   '10.9',
#   '',
#   '80',
#   '0.9',
#   '59',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-15',
#   '17',
#   '1022.1',
#   '',
#   '11.0',
#   '',
#   '78',
#   '0.9',
#   '72',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-15',
#   '18',
#   '1022.3',
#   '',
#   '11.4',
#   '',
#   '70',
#   '0.9',
#   '64',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-15',
#   '19',
#   '1023.0',
#   '',
#   '11.7',
#   '',
#   '65',
#   '0.6',
#   '57',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-15',
#   '20',
#   '1023.8',
#   '',
#   '12.1',
#   '',
#   '62',
#   '0.9',
#   '61',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
# ...
#   '13.1',
#   '',
#   '85',
#   '1.0',
#   '74',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-25',
#   '3',
#   '1027.1',
#   '',
#   '13.1',
#   '',
#   '84',
#   '0.9',
#   '79',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-25',
#   '4',
#   '1026.9',
#   '',
#   '13.4',
#   '',
#   '81',
#   '0.9',
#   '80',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-25',
#   '5',
#   '1027.5',
#   '',
#   '13.2',
#   '',
#   '84',
#   '0.8',
#   '88',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-25',
#   '6',
#   '1028.2',
#   '',
#   '13.2',
#   '',
#   '86',
#   '0.9',
#   '90',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-25',
#   '7',
#   '1028.7',
#   '',
#   '13.1',
#   '',
#   '88',
#   '1.0',
#   '94',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-25',
#   '8',
#   '1029.0',
#   '',
#   '13.5',
#   '',
#   '86',
#   '1.1',
#   '99',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-25',
#   '9',
#   '1029.2',
#   '',
#   '14.1',
#   '',
#   '81',
#   '1.2',
#   '73',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-25',
#   '10',
#   '1028.8',
#   '',
#   '14.4',
#   '',
#   '78',
#   '1.3',
#   '86',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-25',
#   '11',
#   '1028.5',
#   '',
#   '14.6',
#   '',
#   '77',
#   '1.2',
#   '94',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-25',
#   '12',
#   '1028.0',
#   '',
#   '14.5',
#   '',
#   '77',
#   '1.3',
#   '83',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-25',
#   '13',
#   '1027.1',
#   '',
#   '14.2',
#   '',
#   '80',
#   '1.0',
#   '85',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-25',
#   '14',
#   '1026.3',
#   '',
#   '14.3',
#   '',
#   '79',
#   '1.2',
#   '100',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-25',
#   '15',
#   '1026.4',
#   '',
#   '14.0',
#   '',
#   '82',
#   '1.1',
#   '77',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-25',
#   '16',
#   '1026.0',
#   '',
#   '13.9',
#   '',
#   '84',
#   '1.0',
#   '84',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-25',
#   '17',
#   '1026.4',
#   '',
#   '13.9',
#   '',
#   '85',
#   '1.1',
#   '94',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-25',
#   '18',
#   '1026.9',
#   '',
#   '13.6',
#   '',
#   '91',
#   '1.0',
#   '92',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-25',
#   '19',
#   '1026.7',
#   '',
#   '13.7',
#   '',
#   '91',
#   '1.1',
#   '95',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-25',
#   '20',
#   '1027.2',
#   '',
#   '13.6',
#   '',
#   '91',
#   '1.0',
#   '85',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-25',
#   '21',
#   '1027.4',
#   '',
#   '13.5',
#   '',
#   '91',
#   '1.0',
#   '84',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-25',
#   '22',
#   '1027.3',
#   '',
#   '13.5',
#   '',
#   '92',
#   '1.3',
#   '90',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-25',
#   '23',
#   '1027.1',
#   '',
#   '13.7',
#   '',
#   '89',
#   '1.2',
#   '89',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-25',
#   '24',
#   '1026.6',
#   '',
#   '13.9',
#   '',
#   '88',
#   '1.0',
#   '87',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-26',
#   '1',
#   '1026.0',
#   '',
#   '13.8',
#   '',
#   '89',
#   '1.1',
#   '89',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-26',
#   '2',
#   '1025.5',
#   '',
#   '13.8',
#   '',
#   '89',
#   '0.9',
#   '101',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-26',
#   '3',
#   '1025.2',
#   '',
#   '13.8',
#   '',
#   '89',
#   '1.0',
#   '86',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-26',
#   '4',
#   '1025.1',
#   '',
#   '13.4',
#   '',
#   '94',
#   '0.9',
#   '94',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-26',
#   '5',
#   '1025.2',
#   '',
#   '13.4',
#   '',
#   '95',
#   '1.1',
#   '98',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-26',
#   '6',
#   '1025.9',
#   '',
#   '13.4',
#   '',
#   '96',
#   '0.8',
#   '84',
#   '',
#   '',
#   '0.5',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-26',
#   '7',
#   '1026.4',
#   '',
#   '13.5',
#   '',
#   '95',
#   '1.0',
#   '72',
#   '',
#   '',
#   '0.5',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-26',
#   '8',
#   '1026.9',
#   '',
#   '13.3',
#   '',
#   '94',
#   '1.1',
#   '101',
#   '',
#   '',
#   '0.5',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-26',
#   '9',
#   '1027.1',
#   '',
#   '13.5',
#   '',
#   '93',
#   '0.9',
#   '95',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-26',
#   '10',
#   '1026.8',
#   '',
#   '13.5',
#   '',
#   '95',
#   '1.2',
#   '93',
#   '',
#   '',
#   '1.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-26',
#   '11',
#   '1026.3',
#   '',
#   '13.8',
#   '',
#   '94',
#   '1.0',
#   '84',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-26',
#   '12',
#   '1025.2',
#   '',
#   '14.0',
#   '',
#   '94',
#   '1.0',
#   '89',
#   '',
#   '',
#   '0.5',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-26',
#   '13',
#   '1024.0',
#   '',
#   '14.0',
#   '',
#   '93',
#   '1.5',
#   '92',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-26',
#   '14',
#   '1022.8',
#   '',
#   '14.2',
#   '',
#   '93',
#   '1.1',
#   '95',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-26',
#   '15',
#   '1022.3',
#   '',
#   '14.3',
#   '',
#   '91',
#   '1.1',
#   '89',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-26',
#   '16',
#   '1022.5',
#   '',
#   '14.2',
#   '',
#   '93',
#   '1.1',
#   '94',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-26',
#   '17',
#   '1022.6',
#   '',
#   '14.1',
#   '',
#   '97',
#   '0.5',
#   '106',
#   '',
#   '',
#   '0.5',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-26',
#   '18',
#   '1022.6',
#   '',
#   '14.1',
#   '',
#   '98',
#   '0.8',
#   '118',
#   '',
#   '',
#   '0.5',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-26',
#   '19',
#   '1022.7',
#   '',
#   '14.5',
#   '',
#   '99',
#   '0.8',
#   '116',
#   '',
#   '',
#   '1.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-26',
#   '20',
#   '1023.3',
#   '',
#   '14.9',
#   '',
#   '98',
#   '0.8',
#   '109',
#   '',
#   '',
#   '1.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-26',
#   '21',
#   '1022.9',
#   '',
#   '15.0',
#   '',
#   '98',
#   '1.4',
#   '107',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-26',
#   '22',
#   '1023.2',
#   '',
#   '15.3',
#   '',
#   '96',
#   '1.1',
#   '99',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-26',
#   '23',
#   '1022.5',
#   '',
#   '15.3',
#   '',
#   '98',
#   '1.1',
#   '101',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-26',
#   '24',
#   '1021.6',
#   '',
#   '15.4',
#   '',
#   '98',
#   '0.9',
#   '106',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-27',
#   '1',
#   '1021.0',
#   '',
#   '15.5',
#   '',
#   '98',
#   '1.2',
#   '105',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-27',
#   '2',
#   '1020.2',
#   '',
#   '15.7',
#   '',
#   '97',
#   '1.2',
#   '115',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-27',
#   '3',
#   '1019.5',
#   '',
#   '15.8',
#   '',
#   '96',
#   '0.5',
#   '345',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-27',
#   '4',
#   '1019.4',
#   '',
#   '15.7',
#   '',
#   '96',
#   '0.9',
#   '265',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-27',
#   '5',
#   '1019.4',
#   '',
#   '15.5',
#   '',
#   '97',
#   '1.2',
#   '275',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-27',
#   '6',
#   'X',
#   '',
#   'X',
#   '',
#   'X',
#   'X',
#   'X',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-27',
#   '7',
#   '1020.2',
#   '',
#   '15.3',
#   '',
#   '99',
#   '0.3',
#   '202',
#   '',
#   '',
#   '1.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-27',
#   '8',
#   '1020.9',
#   '',
#   '15.3',
#   '',
#   '98',
#   '0.2',
#   '0',
#   '',
#   '',
#   '1.5',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-27',
#   '9',
#   '1021.5',
#   '',
#   '15.3',
#   '',
#   '99',
#   '0.9',
#   '285',
#   '',
#   '',
#   '1.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-27',
#   '10',
#   '1021.4',
#   '',
#   '15.4',
#   '',
#   '98',
#   '0.4',
#   '180',
#   '',
#   '',
#   '1.5',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-27',
#   '11',
#   '1021.4',
#   '',
#   '15.4',
#   '',
#   '99',
#   '1.2',
#   '241',
#   '',
#   '',
#   '1.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-27',
#   '12',
#   '1021.3',
#   '',
#   '15.3',
#   '',
#   '98',
#   '0.3',
#   '349',
#   '',
#   '',
#   '1.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-27',
#   '13',
#   '1020.1',
#   '',
#   '15.7',
#   '',
#   '98',
#   '0.5',
#   '329',
#   '',
#   '',
#   '1.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-27',
#   '14',
#   '1019.5',
#   '',
#   '15.7',
#   '',
#   '97',
#   '0.4',
#   '192',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-27',
#   '15',
#   '1019.2',
#   '',
#   '16.2',
#   '',
#   '90',
#   '1.2',
#   '76',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-27',
#   '16',
#   '1019.4',
#   '',
#   '16.1',
#   '',
#   '91',
#   '0.6',
#   '84',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-27',
#   '17',
#   '1019.9',
#   '',
#   '15.8',
#   '',
#   '91',
#   '0.9',
#   '101',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-27',
#   '18',
#   '1019.9',
#   '',
#   '15.6',
#   '',
#   '94',
#   '1.0',
#   '106',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-27',
#   '19',
#   '1020.4',
#   '',
#   '15.6',
#   '',
#   '93',
#   '1.0',
#   '111',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-27',
#   '20',
#   '1021.0',
#   '',
#   '15.4',
#   '',
#   '94',
#   '1.0',
#   '142',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-27',
#   '21',
#   '1021.2',
#   '',
#   '15.4',
#   '',
#   '94',
#   '0.5',
#   '114',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-27',
#   '22',
#   '1021.0',
#   '',
#   '15.3',
#   '',
#   '97',
#   '0.7',
#   '120',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-27',
#   '23',
#   '1021.3',
#   '',
#   '15.3',
#   '',
#   '97',
#   '0.0',
#   '0',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-27',
#   '24',
#   '1021.1',
#   '',
#   '15.4',
#   '',
#   '95',
#   '0.4',
#   '171',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-28',
#   '1',
#   '1020.5',
#   '',
#   '15.5',
#   '',
#   '96',
#   '0.0',
#   '0',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-28',
#   '2',
#   '1020.3',
#   '',
#   '15.3',
#   '',
#   '97',
#   '0.6',
#   '152',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-28',
#   '3',
#   '1019.4',
#   '',
#   '15.2',
#   '',
#   '97',
#   '0.7',
#   '47',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-28',
#   '4',
#   '1019.2',
#   '',
#   '15.1',
#   '',
#   '97',
#   '0.2',
#   '0',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-28',
#   '5',
#   '1019.2',
#   '',
#   '15.2',
#   '',
#   '97',
#   '0.3',
#   '37',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-28',
#   '6',
#   '1019.7',
#   '',
#   '15.2',
#   '',
#   '97',
#   '0.9',
#   '60',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-28',
#   '7',
#   '1020.0',
#   '',
#   '15.2',
#   '',
#   '97',
#   '0.2',
#   '0',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-28',
#   '8',
#   '1020.4',
#   '',
#   '16.9',
#   '',
#   '86',
#   '0.9',
#   '99',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-28',
#   '9',
#   '1021.0',
#   '',
#   '18.6',
#   '',
#   '73',
#   '1.4',
#   '80',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-28',
#   '10',
#   '1020.6',
#   '',
#   '19.7',
#   '',
#   '62',
#   '2.1',
#   '81',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-28',
#   '11',
#   '1020.0',
#   '',
#   '20.7',
#   '',
#   '57',
#   '1.9',
#   '66',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-28',
#   '12',
#   '1019.0',
#   '',
#   '21.0',
#   '',
#   '58',
#   '2.5',
#   '38',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-28',
#   '13',
#   '1018.1',
#   '',
#   '21.5',
#   '',
#   '55',
#   '2.3',
#   '62',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-28',
#   '14',
#   '1017.5',
#   '',
#   '21.2',
#   '',
#   '56',
#   '2.5',
#   '81',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-28',
#   '15',
#   '1017.3',
#   '',
#   '20.9',
#   '',
#   '57',
#   '2.0',
#   '74',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-28',
#   '16',
#   '1017.5',
#   '',
#   '20.7',
#   '',
#   '56',
#   '2.1',
#   '67',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-28',
#   '17',
#   '1017.6',
#   '',
#   '19.9',
#   '',
#   '59',
#   '1.7',
#   '69',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-28',
#   '18',
#   '1018.5',
#   '',
#   '19.2',
#   '',
#   '64',
#   '1.6',
#   '66',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-28',
#   '19',
#   '1018.7',
#   '',
#   '18.6',
#   '',
#   '67',
#   '1.4',
#   '83',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-28',
#   '20',
#   '1019.4',
#   '',
#   '18.1',
#   '',
#   '71',
#   '0.9',
#   '108',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-28',
#   '21',
#   '1020.0',
#   '',
#   '17.4',
#   '',
#   '77',
#   '1.2',
#   '112',
#   '',
#   '',
#   'X',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-28',
#   '22',
#   '1019.8',
#   '',
#   '17.1',
#   '',
#   '78',
#   '1.3',
#   '119',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-28',
#   '23',
#   '1019.4',
#   '',
#   '17.0',
#   '',
#   '79',
#   '0.2',
#   '0',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-28',
#   '24',
#   '1020.0',
#   '',
#   '16.7',
#   '',
#   '81',
#   '0.9',
#   '356',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-29',
#   '1',
#   '1020.0',
#   '',
#   '17.1',
#   '',
#   '80',
#   '1.1',
#   '97',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-29',
#   '2',
#   '1020.1',
#   '',
#   '16.6',
#   '',
#   '84',
#   '1.4',
#   '128',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-29',
#   '3',
#   '1020.4',
#   '',
#   '16.1',
#   '',
#   '87',
#   '1.3',
#   '76',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-29',
#   '4',
#   '1020.5',
#   '',
#   '15.8',
#   '',
#   '88',
#   '1.5',
#   '71',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-29',
#   '5',
#   '1021.3',
#   '',
#   '15.5',
#   '',
#   '90',
#   '0.0',
#   '0',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-29',
#   '6',
#   '1022.7',
#   '',
#   '17.1',
#   '',
#   '75',
#   '2.7',
#   '54',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-29',
#   '7',
#   '1024.0',
#   '',
#   '17.0',
#   '',
#   '71',
#   '1.8',
#   '59',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-29',
#   '8',
#   '1025.2',
#   '',
#   '16.5',
#   '',
#   '69',
#   '2.4',
#   '53',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-29',
#   '9',
#   '1025.8',
#   '',
#   '16.4',
#   '',
#   '63',
#   '1.5',
#   '66',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-29',
#   '10',
#   '1026.0',
#   '',
#   '17.1',
#   '',
#   '58',
#   '1.5',
#   '57',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-29',
#   '11',
#   '1025.8',
#   '',
#   '16.8',
#   '',
#   '62',
#   '2.2',
#   '73',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-29',
#   '12',
#   '1025.3',
#   '',
#   '17.4',
#   '',
#   '59',
#   '1.8',
#   '75',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-29',
#   '13',
#   '1024.8',
#   '',
#   '17.2',
#   '',
#   '61',
#   '2.7',
#   '45',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-29',
#   '14',
#   '1024.3',
#   '',
#   '16.9',
#   '',
#   '61',
#   '2.4',
#   '58',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-29',
#   '15',
#   '1024.5',
#   '',
#   '16.0',
#   '',
#   '63',
#   '2.3',
#   '51',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-29',
#   '16',
#   '1024.8',
#   '',
#   '15.4',
#   '',
#   '60',
#   '1.9',
#   '67',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-29',
#   '17',
#   '1025.4',
#   '',
#   '15.1',
#   '',
#   '58',
#   '2.0',
#   '58',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-29',
#   '18',
#   '1025.5',
#   '',
#   '15.0',
#   '',
#   '57',
#   '1.6',
#   '76',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-29',
#   '19',
#   '1026.0',
#   '',
#   '14.8',
#   '',
#   '57',
#   '1.6',
#   '93',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-29',
#   '20',
#   '1026.6',
#   '',
#   '14.5',
#   '',
#   '59',
#   '1.0',
#   '102',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-29',
#   '21',
#   '1027.0',
#   '',
#   '14.2',
#   '',
#   '58',
#   '1.6',
#   '113',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-29',
#   '22',
#   '1027.3',
#   '',
#   '13.8',
#   '',
#   '54',
#   '1.4',
#   '97',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-29',
#   '23',
#   '1027.0',
#   '',
#   '13.6',
#   '',
#   '52',
#   '1.6',
#   '115',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2016-02-29',
#   '24',
#   '1026.4',
#   '',
#   '12.9',
#   '',
#   '58',
#   '1.3',
#   '113',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   '']]

# %%
len(tr_list)
# Out:
# 696

# %%
# testing for getting one page information (02-01)

page_url = "http://e-service.cwb.gov.tw/HistoryDataQuery/DayDataController.do?command=viewMain&station=C0A9G0&stname=%25E5%258D%2597%25E6%25B8%25AF&datepicker=2016-02-01"
res = r.get(page_url)
res.encoding = 'utf-8' # 調整Response obect的encoding，不然中文是亂碼
soup = BeautifulSoup(res.text, 'html5lib')

# %% [markdown]
# ### making a list of column names
# list name : column_names

# %%
column_name_unformat = []
column_names = []
#soup.select("th")[9]
column_names.append('date') 

for i in range(9, 24):
    col_title_unformat = soup.select("th")[i]
    col_title = "%s"%col_title_unformat
    
    column_name_unformat.append(col_title)
    #col_title = col_title.split("<th>")[1]
    #print(col_title)
#column_name

for i in column_name_unformat :
    col_title = i.split('<th>')[1].split("</th>")[0].replace("<br/>", " ")
    
    column_names.append(col_title)
    
    #print(col_title)

   
column_names
# Out:
# ['date',
#  '觀測時間 (LST) ObsTime',
#  '測站氣壓 (hPa) StnPres',
#  '海平面氣壓 (hPa) SeaPres',
#  '氣溫 (℃) Temperature',
#  '露點溫度 (℃) Td dew point',
#  '相對溼度 (%) RH',
#  '風速 (m/s) WS',
#  '風向 (360degree) WD',
#  '最大陣風 (m/s) WSGust',
#  '最大陣風風向 (360degree) WDGust',
#  '降水量 (mm) Precp',
#  '降水時數 (hr) PrecpHour ',
#  '日照時數 (hr) SunShine',
#  '全天空日射量 (MJ/㎡) GloblRad',
#  '能見度 (km) Visb']

# %% [markdown]
# ### crawling the data in cell (weather data)

# %%
tr_list = []
for i in range(3, 27):
    ii =soup.select("tr" )[i]
    tr_set = "%s"%ii
    tr_set = tr_set.replace("\n\t\t", "").replace("\xa0", "").replace("<tr>", "")\
    .replace("</tr>", "").replace('<td nowrap="">', "").replace("</td>", ",").replace("<td>", "")\
    .replace("\t", "").replace("\n\t", '').replace('\n', '').replace(" ", "")
    #print(ii)
    tr_list.append(tr_set)

# %%
tr_list
# Out:
# ['1,1017.3,,17.6,,94,1.2,74,,,0.0,,,,,',
#  '2,1017.4,,17.3,,94,1.3,81,,,0.5,,,,,',
#  '3,1017.5,,17.1,,91,1.2,69,,,0.0,,,,,',
#  '4,1018.4,,16.4,,90,1.3,61,,,0.0,,,,,',
#  '5,1019.6,,15.8,,88,0.9,67,,,0.0,,,,,',
#  '6,1020.3,,15.1,,90,1.3,68,,,0.0,,,,,',
#  '7,1021.2,,14.3,,89,1.3,68,,,1.0,,,,,',
#  '8,1022.2,,13.7,,89,1.3,58,,,0.0,,,,,',
#  '9,1022.4,,13.8,,91,1.3,65,,,1.5,,,,,',
#  '10,1022.9,,13.9,,90,1.1,60,,,0.0,,,,,',
#  '11,1022.5,,13.9,,88,1.4,59,,,1.0,,,,,',
#  '12,1021.6,,14.0,,90,0.6,61,,,0.5,,,,,',
#  '13,1020.9,,13.8,,91,0.8,63,,,2.5,,,,,',
#  '14,1020.2,,13.7,,90,0.9,64,,,1.0,,,,,',
#  '15,1020.0,,13.8,,88,0.9,62,,,0.5,,,,,',
#  '16,1020.7,,13.4,,90,0.7,69,,,0.5,,,,,',
#  '17,1021.8,,13.2,,89,0.9,38,,,1.0,,,,,',
#  '18,1022.3,,12.6,,88,0.8,69,,,0.5,,,,,',
#  '19,1023.6,,12.3,,88,1.0,70,,,2.0,,,,,',
#  '20,1023.5,,12.1,,89,0.7,76,,,0.5,,,,,',
#  '21,1023.4,,12.1,,90,0.7,60,,,1.5,,,,,',
#  '22,1023.3,,12.0,,90,0.8,68,,,1.0,,,,,',
#  '23,1023.3,,11.9,,90,1.0,70,,,1.0,,,,,',
#  '24,1022.8,,11.9,,90,0.7,63,,,0.5,,,,,']

# %%
import pandas as pd
one_record = []

ObsTime = []
StnPres = []
SeaPres = []
Temperature = []
Td_dew_point = []
RH = []
WS = []
WD = []
WSGust = []
WDGust = []
Precp = []
PrecpHour = []
SunShine = []
GloblRad = []
Visb = []


for i in tr_list :
    one_record.append(i.split(','))
    
for i in one_record :
    ObsTime.append(i[0])
    StnPres.append(i[1])
    SeaPres.append(i[2])
    Temperature.append(i[3])
    Td_dew_point.append(i[4])
    RH.append(i[5])
    WS.append(i[6])
    WD.append(i[7])
    WSGust.append(i[8])
    WDGust.append(i[9])
    Precp.append(i[10])
    PrecpHour.append(i[11])
    SunShine.append(i[12])
    GloblRad.append(i[13])
    Visb.append(i[14])

one_record
#ObsTime
# Out:
# [['1',
#   '1017.3',
#   '',
#   '17.6',
#   '',
#   '94',
#   '1.2',
#   '74',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2',
#   '1017.4',
#   '',
#   '17.3',
#   '',
#   '94',
#   '1.3',
#   '81',
#   '',
#   '',
#   '0.5',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['3',
#   '1017.5',
#   '',
#   '17.1',
#   '',
#   '91',
#   '1.2',
#   '69',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['4',
#   '1018.4',
#   '',
#   '16.4',
#   '',
#   '90',
#   '1.3',
#   '61',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['5',
#   '1019.6',
#   '',
#   '15.8',
#   '',
#   '88',
#   '0.9',
#   '67',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['6',
#   '1020.3',
#   '',
#   '15.1',
#   '',
#   '90',
#   '1.3',
#   '68',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['7',
#   '1021.2',
#   '',
#   '14.3',
#   '',
#   '89',
#   '1.3',
#   '68',
#   '',
#   '',
#   '1.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['8',
#   '1022.2',
#   '',
#   '13.7',
#   '',
#   '89',
#   '1.3',
#   '58',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['9',
#   '1022.4',
#   '',
#   '13.8',
#   '',
#   '91',
#   '1.3',
#   '65',
#   '',
#   '',
#   '1.5',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['10',
#   '1022.9',
#   '',
#   '13.9',
#   '',
#   '90',
#   '1.1',
#   '60',
#   '',
#   '',
#   '0.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['11',
#   '1022.5',
#   '',
#   '13.9',
#   '',
#   '88',
#   '1.4',
#   '59',
#   '',
#   '',
#   '1.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['12',
#   '1021.6',
#   '',
#   '14.0',
#   '',
#   '90',
#   '0.6',
#   '61',
#   '',
#   '',
#   '0.5',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['13',
#   '1020.9',
#   '',
#   '13.8',
#   '',
#   '91',
#   '0.8',
#   '63',
#   '',
#   '',
#   '2.5',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['14',
#   '1020.2',
#   '',
#   '13.7',
#   '',
#   '90',
#   '0.9',
#   '64',
#   '',
#   '',
#   '1.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['15',
#   '1020.0',
#   '',
#   '13.8',
#   '',
#   '88',
#   '0.9',
#   '62',
#   '',
#   '',
#   '0.5',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['16',
#   '1020.7',
#   '',
#   '13.4',
#   '',
#   '90',
#   '0.7',
#   '69',
#   '',
#   '',
#   '0.5',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['17',
#   '1021.8',
#   '',
#   '13.2',
#   '',
#   '89',
#   '0.9',
#   '38',
#   '',
#   '',
#   '1.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['18',
#   '1022.3',
#   '',
#   '12.6',
#   '',
#   '88',
#   '0.8',
#   '69',
#   '',
#   '',
#   '0.5',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['19',
#   '1023.6',
#   '',
#   '12.3',
#   '',
#   '88',
#   '1.0',
#   '70',
#   '',
#   '',
#   '2.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['20',
#   '1023.5',
#   '',
#   '12.1',
#   '',
#   '89',
#   '0.7',
#   '76',
#   '',
#   '',
#   '0.5',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['21',
#   '1023.4',
#   '',
#   '12.1',
#   '',
#   '90',
#   '0.7',
#   '60',
#   '',
#   '',
#   '1.5',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['22',
#   '1023.3',
#   '',
#   '12.0',
#   '',
#   '90',
#   '0.8',
#   '68',
#   '',
#   '',
#   '1.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['23',
#   '1023.3',
#   '',
#   '11.9',
#   '',
#   '90',
#   '1.0',
#   '70',
#   '',
#   '',
#   '1.0',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['24',
#   '1022.8',
#   '',
#   '11.9',
#   '',
#   '90',
#   '0.7',
#   '63',
#   '',
#   '',
#   '0.5',
#   '',
#   '',
#   '',
#   '',
#   '']]

# %%
Temperature
# Out:
# ['17.6',
#  '17.3',
#  '17.1',
#  '16.4',
#  '15.8',
#  '15.1',
#  '14.3',
#  '13.7',
#  '13.8',
#  '13.9',
#  '13.9',
#  '14.0',
#  '13.8',
#  '13.7',
#  '13.8',
#  '13.4',
#  '13.2',
#  '12.6',
#  '12.3',
#  '12.1',
#  '12.1',
#  '12.0',
#  '11.9',
#  '11.9']

# %% [markdown]
# ### making the data list togeter into a zip dataset

# %%
# using zip function

 

WeatherDataSet = list(zip(date,ObsTime,StnPres,SeaPres,Temperature,Td_dew_point,RH,WS,WD,WSGust,WDGust,Precp,PrecpHour,SunShine,GloblRad,Visb))
#WeatherDataSet
df = pd.DataFrame(data = WeatherDataSet, column_names)

df
# Out:
#    ObsTime StnPres SeaPres Temperature Td_dew_point  RH   WS  WD WSGust  \
# 0        1  1017.3                17.6               94  1.2  74
# 1        2  1017.4                17.3               94  1.3  81
# 2        3  1017.5                17.1               91  1.2  69
# 3        4  1018.4                16.4               90  1.3  61
# 4        5  1019.6                15.8               88  0.9  67
# 5        6  1020.3                15.1               90  1.3  68
# 6        7  1021.2                14.3               89  1.3  68
# 7        8  1022.2                13.7               89  1.3  58
# 8        9  1022.4                13.8               91  1.3  65
# 9       10  1022.9                13.9               90  1.1  60
# 10      11  1022.5                13.9               88  1.4  59
# 11      12  1021.6                14.0               90  0.6  61
# 12      13  1020.9                13.8               91  0.8  63
# 13      14  1020.2                13.7               90  0.9  64
# 14      15  1020.0                13.8               88  0.9  62
# 15      16  1020.7                13.4               90  0.7  69
# 16      17  1021.8                13.2               89  0.9  38
# 17      18  1022.3                12.6               88  0.8  69
# 18      19  1023.6                12.3               88  1.0  70
# 19      20  1023.5                12.1               89  0.7  76
# 20      21  1023.4                12.1               90  0.7  60
# 21      22  1023.3                12.0               90  0.8  68
# 22      23  1023.3                11.9               90  1.0  70
# 23      24  1022.8                11.9               90  0.7  63
#
#    WDGust Precp PrecpHour SunShine GloblRad Visb
# 0           0.0
# 1           0.5
# 2           0.0
# 3           0.0
# 4           0.0
# 5           0.0
# 6           1.0
# 7           0.0
# 8           1.5
# 9           0.0
# 10          1.0
# 11          0.5
# 12          2.5
# 13          1.0
# 14          0.5
# 15          0.5
# 16          1.0
# 17          0.5
# 18          2.0
# 19          0.5
# 20          1.5
# 21          1.0
# 22          1.0
# 23          0.5

# %%
# something description

ObsTime.append(one_record[0])
    StnPres.append(one_record[1])
    SeaPres.append(one_record[2])
    Temperature.append(one_record[3])
    Td_dew_point.append(one_record[4])
    RH.append(one_record[5])
    WS.append(one_record[6])
    WD.append(one_record[7])
    WSGust.append(one_record[8])
    WDGust.append(one_record[9])
    Precp.append(one_record[10])
    PrecpHour.append(one_record[11])
    SunShine.append(one_record[12])
    GloblRad.append(one_record[13])
    Visb.append(one_record[14])

# %%
len(soup.select("tr"))
# Out:
# 27

# %%
# getting out the data and make it into a dataset

for i in tr_list :
# Out:
# <tr>
# 		<td nowrap="">24</td>
# 		<td>1022.8 </td>
# 		<td> </td>
# 		<td>11.9 </td>
# 		<td> </td>
# 		<td>90 </td>
# 		<td>0.7 </td>
# 		<td>63 </td>
# 		<td> </td>
# 		<td> </td>
# 		<td>0.5 </td>
# 		<td> </td>
# 		<td> </td>
# 		<td> </td>
# 		<td> </td>
# 	 </tr>
